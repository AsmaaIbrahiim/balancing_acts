# %%
import numpy as np
import torch
import glob
from PIL import Image
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader,Dataset
import torchvision.transforms as tt
import torch.optim as optim
from torchvision.utils import make_grid
import matplotlib.pyplot as plt

# %%
TRAIN_DIR = "E:\\Aquib\\MCA\\Python\\Fatima Fellowship\\datasets\\cell_images\\train\\"
VAl_DIR = "E:\\Aquib\\MCA\\Python\\Fatima Fellowship\\datasets\\cell_images\\test\\"
BATCH_SIZE = 32
LEARNING_RATE = 1e-3
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
class Cell(Dataset):
    def __init__(self,root_dir,transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.data = []
        list_files = glob.glob(self.root_dir + "*")
        # print(list_files)
        for class_path in list_files:
            class_name = class_path.split("\\")[-1]
            for img_path in glob.glob(class_path + "\\*.png"):
                self.data.append([img_path,class_name])
        self.class_map = {"parasitized":0, "uninfected":1}

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        img_path,class_name = self.data[index]
        img = Image.open(img_path).convert('RGB')
        label = self.class_map[class_name]
        label = torch.tensor(label)
        if self.transform is not None:
            img = self.transform(img)
        return img,label


# if __name__=='__main__':
  

#     # print(len(loader))
#     for x,y in loader:
#         print(x.shape)
#         print(y)
#         import sys
#         sys.exit()

# %%
trans = tt.Compose([
    tt.Resize((64,64)),
    tt.ToTensor(),
    ])
train_dataset = Cell(TRAIN_DIR,transform = trans)
val_dataset = Cell(VAl_DIR,transform = trans)
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)

# %%
def show_batch(dl):
    for images,labels in dl:
        fig,ax = plt.subplots(figsize=(12,12))
        ax.set_xticks([]);ax.set_yticks([])
        ax.imshow(make_grid(images[:50],nrow=10).permute(1,2,0))
        break

# %%
show_batch(dl=train_loader)

# %% [markdown]
# ## Define a CNN Model

# %%
class CNNBlock(nn.Module):
    def __init__(self,in_channels,out_channels):
        super(CNNBlock,self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels,out_channels,kernel_size=3,stride=1,padding=1),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(out_channels)
        )
    
    def forward(self,x):
        return self.conv(x)


class Model(nn.Module):
    def __init__(self):
        super(Model,self).__init__()
        self.conv1 = CNNBlock(3,64)
        self.conv2 = CNNBlock(64,128)
        self.conv3 = CNNBlock(128,512)
        self.pool = nn.MaxPool2d(kernel_size=(2,2))
        self.linear1 = nn.Linear(512*8*8,1024)
        self.linear2 = nn.Linear(1024,512)
        self.linear3 = nn.Linear(512,2)


    def forward(self,x):
        x = self.conv1(x)
        x= self.pool(x)
        x = self.conv2(x)
        x= self.pool(x)
        x = self.conv3(x)
        x= self.pool(x)
        x = x.reshape(x.shape[0],-1)
        x = F.relu(self.linear1(x))
        x = F.relu(self.linear2(x))
        x = self.linear3(x)
        return x

# %%
model = Model().to(DEVICE)

# %%
model.parameters
# Out:
# <bound method Module.parameters of Model(
#   (conv1): CNNBlock(
#     (conv): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv2): CNNBlock(
#     (conv): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv3): CNNBlock(
#     (conv): Sequential(
#       (0): Conv2d(128, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (linear1): Linear(in_features=32768, out_features=1024, bias=True)
#   (linear2): Linear(in_features=1024, out_features=512, bias=True)
#   (linear3): Linear(in_features=512, out_features=2, bias=True)
# )>

# %%
optimizer = optim.Adam(model.parameters(),lr=LEARNING_RATE)
criterion = nn.CrossEntropyLoss()

# %%
n_epochs = 5
print_every = 10
valid_loss_min = np.Inf
val_loss = []
val_acc = []
train_loss = []
train_acc = []
total_step = len(train_loader)
for epoch in range(1, n_epochs+1):
    running_loss = 0.0
    correct = 0
    total=0
    print(f'Epoch {epoch}\n')
    for batch_idx, (data_, target_) in enumerate(train_loader):
        data_, target_ = data_.to(DEVICE), target_.to(DEVICE)
        optimizer.zero_grad()
        
        outputs = model(data_)
        loss = criterion(outputs, target_)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _,pred = torch.max(outputs, dim=1)
        correct += torch.sum(pred==target_).item()
        total += target_.size(0)
        if (batch_idx) % 20 == 0:
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                   .format(epoch, n_epochs, batch_idx, total_step, loss.item()))
    train_acc.append(100 * correct / total)
    train_loss.append(running_loss/total_step)
    print(f'\ntrain-loss: {np.mean(train_loss):.4f}, train-acc: {(100 * correct/total):.4f}')
    batch_loss = 0
    total_t=0
    correct_t=0
    with torch.no_grad():
        model.eval()
        for data_t, target_t in (val_loader):
            data_t, target_t = data_t.to(DEVICE), target_t.to(DEVICE)
            outputs_t = model(data_t)
            loss_t = criterion(outputs_t, target_t)
            batch_loss += loss_t.item()
            _,pred_t = torch.max(outputs_t, dim=1)
            correct_t += torch.sum(pred_t==target_t).item()
            total_t += target_t.size(0)
        val_acc.append(100 * correct_t/total_t)
        val_loss.append(batch_loss/len(val_loader))
        network_learned = batch_loss < valid_loss_min
        print(f'validation loss: {np.mean(val_loss):.4f}, validation acc: {(100 * correct_t/total_t):.4f}\n')
# Out:
# Epoch 1
#
# Epoch [1/5], Step [0/532], Loss: 0.8317
# Epoch [1/5], Step [20/532], Loss: 0.4956
# Epoch [1/5], Step [40/532], Loss: 0.4739
# Epoch [1/5], Step [60/532], Loss: 0.4092
# Epoch [1/5], Step [80/532], Loss: 0.2929
# Epoch [1/5], Step [100/532], Loss: 0.3267
# Epoch [1/5], Step [120/532], Loss: 0.7282
# Epoch [1/5], Step [140/532], Loss: 0.5233
# Epoch [1/5], Step [160/532], Loss: 0.3763
# Epoch [1/5], Step [180/532], Loss: 0.3121
# Epoch [1/5], Step [200/532], Loss: 0.5571
# Epoch [1/5], Step [220/532], Loss: 0.3984
# Epoch [1/5], Step [240/532], Loss: 0.3971
# Epoch [1/5], Step [260/532], Loss: 0.4044
# Epoch [1/5], Step [280/532], Loss: 0.3172
# Epoch [1/5], Step [300/532], Loss: 0.2996
# Epoch [1/5], Step [320/532], Loss: 0.1550
# Epoch [1/5], Step [340/532], Loss: 0.0765
# Epoch [1/5], Step [360/532], Loss: 0.0598
# Epoch [1/5], Step [380/532], Loss: 0.2896
# Epoch [1/5], Step [400/532], Loss: 0.2031
# Epoch [1/5], Step [420/532], Loss: 0.3109
# Epoch [1/5], Step [440/532], Loss: 0.0710
# Epoch [1/5], Step [460/532], Loss: 0.0984
# Epoch [1/5], Step [480/532], Loss: 0.2361
# Epoch [1/5], Step [500/532], Loss: 0.1417
# Epoch [1/5], Step [520/532], Loss: 0.1195
#
# train-loss: 0.3836, train-acc: 85.4935
# validation loss: 0.3039, validation acc: 88.9615
#
# Epoch 2
#
# Epoch [2/5], Step [0/532], Loss: 0.0453
# Epoch [2/5], Step [20/532], Loss: 0.0341
# Epoch [2/5], Step [40/532], Loss: 0.0870
# Epoch [2/5], Step [60/532], Loss: 0.1550
# Epoch [2/5], Step [80/532], Loss: 0.0935
# Epoch [2/5], Step [100/532], Loss: 0.6714
# Epoch [2/5], Step [120/532], Loss: 0.0407
# Epoch [2/5], Step [140/532], Loss: 0.0534
# Epoch [2/5], Step [160/532], Loss: 0.1258
# Epoch [2/5], Step [180/532], Loss: 0.0245
# Epoch [2/5], Step [200/532], Loss: 0.1113
# Epoch [2/5], Step [220/532], Loss: 0.2148
# Epoch [2/5], Step [240/532], Loss: 0.4289
# Epoch [2/5], Step [260/532], Loss: 0.1214
# Epoch [2/5], Step [280/532], Loss: 0.2805
# Epoch [2/5], Step [300/532], Loss: 0.2532
# Epoch [2/5], Step [320/532], Loss: 0.1642
# Epoch [2/5], Step [340/532], Loss: 0.1077
# Epoch [2/5], Step [360/532], Loss: 0.1377
# Epoch [2/5], Step [380/532], Loss: 0.0834
# Epoch [2/5], Step [400/532], Loss: 0.1250
# Epoch [2/5], Step [420/532], Loss: 0.0185
# Epoch [2/5], Step [440/532], Loss: 0.0246
# Epoch [2/5], Step [460/532], Loss: 0.3239
# Epoch [2/5], Step [480/532], Loss: 0.0827
# Epoch [2/5], Step [500/532], Loss: 0.1711
# Epoch [2/5], Step [520/532], Loss: 0.0786
#
# train-loss: 0.2651, train-acc: 95.6463
# validation loss: 0.2984, validation acc: 92.4615
#
# Epoch 3
#
# Epoch [3/5], Step [0/532], Loss: 0.0133
# Epoch [3/5], Step [20/532], Loss: 0.1847
# Epoch [3/5], Step [40/532], Loss: 0.0957
# Epoch [3/5], Step [60/532], Loss: 0.1367
# Epoch [3/5], Step [80/532], Loss: 0.1102
# Epoch [3/5], Step [100/532], Loss: 0.1710
# Epoch [3/5], Step [120/532], Loss: 0.0630
# Epoch [3/5], Step [140/532], Loss: 0.2107
# Epoch [3/5], Step [160/532], Loss: 0.0492
# Epoch [3/5], Step [180/532], Loss: 0.0581
# Epoch [3/5], Step [200/532], Loss: 0.2871
# Epoch [3/5], Step [220/532], Loss: 0.1203
# Epoch [3/5], Step [240/532], Loss: 0.1490
# Epoch [3/5], Step [260/532], Loss: 0.1549
# Epoch [3/5], Step [280/532], Loss: 0.0306
# Epoch [3/5], Step [300/532], Loss: 0.1320
# Epoch [3/5], Step [320/532], Loss: 0.0143
# Epoch [3/5], Step [340/532], Loss: 0.1409
# Epoch [3/5], Step [360/532], Loss: 0.1831
# Epoch [3/5], Step [380/532], Loss: 0.2071
# Epoch [3/5], Step [400/532], Loss: 0.0270
# Epoch [3/5], Step [420/532], Loss: 0.0716
# Epoch [3/5], Step [440/532], Loss: 0.1870
# Epoch [3/5], Step [460/532], Loss: 0.0439
# Epoch [3/5], Step [480/532], Loss: 0.0671
# Epoch [3/5], Step [500/532], Loss: 0.0346
# Epoch [3/5], Step [520/532], Loss: 0.1350
#
# train-loss: 0.2163, train-acc: 96.4747
# validation loss: 0.2789, validation acc: 92.3462
#
# Epoch 4
#
# Epoch [4/5], Step [0/532], Loss: 0.0529
# Epoch [4/5], Step [20/532], Loss: 0.0625
# Epoch [4/5], Step [40/532], Loss: 0.0233
# Epoch [4/5], Step [60/532], Loss: 0.0159
# Epoch [4/5], Step [80/532], Loss: 0.1649
# Epoch [4/5], Step [100/532], Loss: 0.1211
# Epoch [4/5], Step [120/532], Loss: 0.0294
# Epoch [4/5], Step [140/532], Loss: 0.0941
# Epoch [4/5], Step [160/532], Loss: 0.0232
# Epoch [4/5], Step [180/532], Loss: 0.1033
# Epoch [4/5], Step [200/532], Loss: 0.0466
# Epoch [4/5], Step [220/532], Loss: 0.1468
# Epoch [4/5], Step [240/532], Loss: 0.0389
# Epoch [4/5], Step [260/532], Loss: 0.1284
# Epoch [4/5], Step [280/532], Loss: 0.1498
# Epoch [4/5], Step [300/532], Loss: 0.0146
# Epoch [4/5], Step [320/532], Loss: 0.0552
# Epoch [4/5], Step [340/532], Loss: 0.0148
# Epoch [4/5], Step [360/532], Loss: 0.0214
# Epoch [4/5], Step [380/532], Loss: 0.0377
# Epoch [4/5], Step [400/532], Loss: 0.0690
# Epoch [4/5], Step [420/532], Loss: 0.0215
# Epoch [4/5], Step [440/532], Loss: 0.0478
# Epoch [4/5], Step [460/532], Loss: 0.0343
# Epoch [4/5], Step [480/532], Loss: 0.1293
# Epoch [4/5], Step [500/532], Loss: 0.0373
# Epoch [4/5], Step [520/532], Loss: 0.0156
#
# train-loss: 0.1882, train-acc: 96.8625
# validation loss: 0.2814, validation acc: 91.1923
#
# Epoch 5
#
# Epoch [5/5], Step [0/532], Loss: 0.0478
# Epoch [5/5], Step [20/532], Loss: 0.1208
# Epoch [5/5], Step [40/532], Loss: 0.0437
# Epoch [5/5], Step [60/532], Loss: 0.0088
# Epoch [5/5], Step [80/532], Loss: 0.0325
# Epoch [5/5], Step [100/532], Loss: 0.0173
# Epoch [5/5], Step [120/532], Loss: 0.1228
# Epoch [5/5], Step [140/532], Loss: 0.1484
# Epoch [5/5], Step [160/532], Loss: 0.1010
# Epoch [5/5], Step [180/532], Loss: 0.0521
# Epoch [5/5], Step [200/532], Loss: 0.0571
# Epoch [5/5], Step [220/532], Loss: 0.0651
# Epoch [5/5], Step [240/532], Loss: 0.0729
# Epoch [5/5], Step [260/532], Loss: 0.1492
# Epoch [5/5], Step [280/532], Loss: 0.0724
# Epoch [5/5], Step [300/532], Loss: 0.0516
# Epoch [5/5], Step [320/532], Loss: 0.0702
# Epoch [5/5], Step [340/532], Loss: 0.1193
# Epoch [5/5], Step [360/532], Loss: 0.0860
# Epoch [5/5], Step [380/532], Loss: 0.2382
# Epoch [5/5], Step [400/532], Loss: 0.1166
# Epoch [5/5], Step [420/532], Loss: 0.4319
# Epoch [5/5], Step [440/532], Loss: 0.0204
# Epoch [5/5], Step [460/532], Loss: 0.1637
# Epoch [5/5], Step [480/532], Loss: 0.0022
# Epoch [5/5], Step [500/532], Loss: 0.0517
# Epoch [5/5], Step [520/532], Loss: 0.0219
#
# train-loss: 0.1711, train-acc: 96.8508
# validation loss: 0.2670, validation acc: 93.8846

# %%
plt.plot(train_loss,label = "train_loss")
plt.plot(val_loss,label = "val_loss")
plt.legend()

# %%
plt.plot(train_acc,label = "train_acc")
plt.plot(val_acc,label = "val_acc")
plt.legend()

# %%
from sklearn.metrics import f1_score
score = []
true = []
pred = []
with torch.no_grad():
        model.eval()
        for data_t, target_t in (val_loader):
            data_t, target_t = data_t.to(DEVICE), target_t.to(DEVICE)
            outputs_t = model(data_t)
            _,pred_t = torch.max(outputs_t, dim=1)
            true.append(target_t.detach().cpu().numpy())
            pred.append(pred_t.detach().cpu().numpy())

# %%
pred_new = []
for x in pred:
    for i in x:
        pred_new.append(i)

# %%
true_new = []
for x in true:
    for i in x:
        true_new.append(i)

# %%
f1_score(true_new,pred_new)
# Out:
# 0.9405162738496072
